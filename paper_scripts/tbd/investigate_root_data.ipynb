# %% [markdown]
# # ROOT Data Investigation
#
# Load one or two ROOT datasets and compare one or two observables.
#
# 1. Edit **Datasets** once below. Each entry names a dataset and provides its ROOT file or files, branches, and optional selection.
# 2. Set **Observables** directly underneath. One observable produces an overlaid 1D histogram; two produce the same sliced 3D histogram panel used for the prediction-process distribution plots.
# 3. Run the remaining cells in order. The notebook validates that every requested observable is available before plotting.
#
# For jagged ROOT branches, use the flattened observable names created by `load_root_events` (for example, `Electron_pt_0`).

# %%
# Setup
import os

from frame.file_structure import LOCAL_PROJECT_ROOT

os.chdir(LOCAL_PROJECT_ROOT)
print(f"Working directory: {os.getcwd()}")

# %% [markdown]
# ## Datasets
#
# Define **one or two** datasets here. `root_files` accepts one local ROOT path, one remote URL, or a list of remote URLs. Include every branch needed by the selection and by the observables below.

# %%
# Edit this single list to compare one or two datasets.
datasets_to_plot = [
    {
        "label": "CMS open data",
        "root_files": "data/cms-open-data/0922B4A4-59D8-2C4E-837E-D5832DEBC7D5.root",
        "branches": [
            "nTau",
            "Tau_eta",
            "Tau_pt",
            "Tau_phi",
            "Tau_charge",
            "nMuon",
            "Muon_pt",
            "Muon_eta",
            "Muon_phi",
            "Muon_charge",
            "nElectron",
            "Electron_pt",
            "Electron_eta",
            "Electron_phi",
            "Electron_charge",
            "nJet",
            "Jet_eta",
            "Jet_pt",
            "Jet_phi",
            "Jet_mass",
        ],
        "observable_renames": {
            "Electron_pt": "Lepton_pt"
        },
        "cut": "(nTau == 1) & (nMuon == 0) & (nElectron == 1)",
        "tree_key": "Events",
    },
]

# %% [markdown]
# ## Observables
#
# Define **one or two** observable names. All selected observables must be loadable from each dataset above.

# %%
# One observable creates an overlaid 1D histogram; two create an overlaid sliced 3D histogram.
observables_to_plot = ["Lepton_pt_0"]

number_of_bins = 50
maximum_events_per_dataset = 100_000
plot_title = "ROOT dataset comparison"

# %%
# Validate the notebook inputs before reading ROOT files.
if not 1 <= len(datasets_to_plot) <= 2:
    raise ValueError("Define one or two datasets in datasets_to_plot.")
if not 1 <= len(observables_to_plot) <= 2:
    raise ValueError("Define one or two observables in observables_to_plot.")
if len(set(observables_to_plot)) != len(observables_to_plot):
    raise ValueError("Observable names must be unique.")
if number_of_bins <= 0:
    raise ValueError("number_of_bins must be positive.")

required_dataset_keys = {"label", "root_files", "branches"}
for dataset_specification in datasets_to_plot:
    missing_keys = required_dataset_keys - dataset_specification.keys()
    if missing_keys:
        raise ValueError(f"Dataset configuration is missing: {sorted(missing_keys)}")
    if not dataset_specification["label"]:
        raise ValueError("Each dataset needs a non-empty label.")

# %%
from frame.file_system.root_reader import load_root_events

loaded_datasets = []
for dataset_specification in datasets_to_plot:
    dataset = load_root_events(
        dataset_specification["root_files"],
        tree_key=dataset_specification.get("tree_key", "Events"),
        branch_names=dataset_specification["branches"],
        observable_renames=dataset_specification.get("observable_renames"),
        cut=dataset_specification.get("cut"),
        aliases=dataset_specification.get("aliases"),
        stop=maximum_events_per_dataset,
    )
    missing_observables = set(observables_to_plot) - set(dataset.observable_names)
    if missing_observables:
        raise ValueError(
            f"{dataset_specification['label']} did not load observables: "
            f"{sorted(missing_observables)}"
        )
    loaded_datasets.append(dataset)

for dataset_specification, dataset in zip(datasets_to_plot, loaded_datasets):
    print(f"{dataset_specification['label']}: {dataset.n_samples:,} events")

# %%
# Inspect the scalar observables that are available after loading.
for dataset_specification, dataset in zip(datasets_to_plot, loaded_datasets):
    print(f"\n{dataset_specification['label']}")
    display(dataset._data.describe().T)

# %%
# Apply the shared plotting design from the standard plot configuration.
from frame.file_system.textual_data import load_dict_from_json
from plot.carpenter import Carpenter
from plot.plotting_config import PlottingConfig

basic_plot_config_path = LOCAL_PROJECT_ROOT / "configs" / "plot" / "basic_plot_config.json"
basic_plot_config = load_dict_from_json(basic_plot_config_path)
# basic_plot_config["run_descriptor"] = "dataset-investigation"
plotting_config = PlottingConfig(**basic_plot_config)
plotting_context = ExecutionContext(
    commit_hash="",
    config=plotting_config,
    config_paths=[basic_plot_config_path],
    command_line_args=[],
    run_hash="root-data-investigation",
)
carpenter = Carpenter(plotting_context)

# %% [markdown]
# ## Comparison plot
#
# The single panel below is intentionally the prediction-process slicing panel: a 1D axis for one observable or a 3D surface-style histogram for two. There is no distribution-ratio subplot.

# %%
import numpy as np
import matplotlib.pyplot as plt

from plot.plot_utils import utils__add_subplot_sliced, utils__datset_histogram_sliced


def display_bins(datasets, observable_names, bin_count):
    """Return shared finite-value histogram edges for each requested observable."""
    bins = []
    for observable_name in observable_names:
        values = np.concatenate([
            np.asarray(dataset.slice_along_observable_names([observable_name])).ravel()
            for dataset in datasets
        ])
        finite_values = values[np.isfinite(values)]
        if finite_values.size == 0:
            raise ValueError(f"{observable_name} has no finite values to plot.")
        bins.append(np.histogram_bin_edges(finite_values, bins=bin_count))
    return bins[0] if len(bins) == 1 else bins


bins = display_bins(loaded_datasets, observables_to_plot, number_of_bins)
number_of_dimensions = len(observables_to_plot)
figure = plt.figure(figsize=(12, 7))
axis = utils__add_subplot_sliced(figure, (1, 1, 1), number_of_dimensions)
colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]

for index, (dataset_specification, dataset) in enumerate(zip(datasets_to_plot, loaded_datasets)):
    utils__datset_histogram_sliced(
        ax=axis,
        bins=bins,
        dataset=dataset,
        along_observables=observables_to_plot,
        label=dataset_specification["label"],
        color=colors[index],
        histtype="step",
        **({"log": True} if number_of_dimensions == 2 else {}),
    )

axis.set_title(plot_title)
axis.set_xlabel(observables_to_plot[0])
if number_of_dimensions == 1:
    axis.set_ylabel("events")
else:
    axis.set_ylabel(observables_to_plot[1])
    axis.set_zlabel("log10(events)")
axis.legend()
figure.tight_layout()
plt.show()
