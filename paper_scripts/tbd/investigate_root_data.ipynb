# %% [markdown]
# # Root Data File Investigation
# Common snippets to uncover what's inside a root file.

# %%
from frame.file_system.root_reader import load_root_events

# %%
# Inputs, equivalent to json file input

file_name = "root://eospublic.cern.ch//eos/opendata/cms/mc/RunIISummer20UL16NanoAODv9/VVTo2L2Nu_MLL-1toInf_TuneCP5_13TeV-amcatnloFXFX-pythia8/NANOAODSIM/106X_mcRun2_asymptotic_v17-v1/30000/0922B4A4-59D8-2C4E-837E-D5832DEBC7D5.root"
dataset_loaded__observable_names = [
    "nTau",
    "Tau_mass",
    "nMuon",
    "Muon_mass",
    "nElectron",
    "Electron_mass"
]
dataset_loaded__cut = None
dataset_loaded__aliases = None
dataset_loaded__event_amount_load_limit = 1000
dataset__detector_binning_maxima = [
    4,
    0.5,
    4,
    0.1056583745,
    4,
    0.000511
]

# %%
events = load_root_events(
    file_name,
    branch_names=dataset_loaded__observable_names,
    cut=dataset_loaded__cut,
    aliases=dataset_loaded__aliases,
    stop=dataset_loaded__event_amount_load_limit,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 events = load_root_events(
#       2     file_name,
#       3     branch_names=dataset_loaded__observable_names,
#       4     cut=dataset_loaded__cut,
#       5     aliases=dataset_loaded__aliases,
#       6     stop=dataset_loaded__event_amount_load_limit,
#       7 )
#
# File ~/LFVNN-symmetrized/frame/file_system/root_reader.py:53, in load_root_events(XRootD_url, tree_key, branch_names, cut, aliases, start, stop)
#      50     error(f"KeyError: One or more branch names {branch_names} do not exist in the ROOT file at {XRootD_url}.")
#      51     raise ke
# ---> 53 return __branches_to_events(arrays, branch_names)
#
# File ~/LFVNN-symmetrized/frame/file_system/root_reader.py:82, in __branches_to_events(arrays, branch_names)
#      78 events = np.column_stack(numpy_arrays)
#      80 info(f"Loaded DataSet with observables: {observable_names}")
# ---> 82 return DataSet(events, observable_names=observable_names)
#
# TypeError: DataSet.__init__() got an unexpected keyword argument 'observable_names'
